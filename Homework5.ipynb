# %% [markdown]
# # Case Intro
# Term deposits are a major source of income for a bank. A term deposit is a cash investment held at a financial institution. Your money is invested for an agreed rate of interest over a fixed amount of time, or term. The bank has various outreach plans to sell term deposits to their customers such as email marketing, advertisements, telephonic marketing, and digital marketing.
#
# Telephonic marketing campaigns still remain one of the most effective way to reach out to people. However, they require huge investment as large call centers are hired to actually execute these campaigns. Hence, it is crucial to identify the customers most likely to convert beforehand so that they can be specifically targeted via call.
#
# The data is related to direct marketing campaigns (phone calls) of a Portuguese banking institution. The classification goal is to predict if the client will subscribe to a term deposit (variable y).
#
# Content
# The data is related to the direct marketing campaigns of a Portuguese banking institution. The marketing campaigns were based on phone calls. Often, more than one contact to the same client was required, in order to access if the product (bank term deposit) would be ('yes') or not ('no') subscribed by the customer or not. The data folder contains two datasets:-
#
# Bank.csv: 45,211 rows and 18 columns ordered by date (from May 2008 to November 2010)
#
# Detailed Column Descriptions
# bank client data:
#
# 1 - age (numeric)
#
# 2 - job : type of job (categorical: "admin.","unknown","unemployed","management","housemaid","entrepreneur","student",
# "blue-collar","self-employed","retired","technician","services")
#
# 3 - marital : marital status (categorical: "married","divorced","single"; note: "divorced" means divorced or widowed)
#
# 4 - education (categorical: "unknown","secondary","primary","tertiary")
#
# 5 - default: has credit in default? (binary: "yes","no")
#
# 6 - balance: average yearly balance, in euros (numeric)
#
# 7 - housing: has housing loan? (binary: "yes","no")
#
# 8 - loan: has personal loan? (binary: "yes","no")
# # related with the last contact of the current campaign:
# 9 - contact: contact communication type (categorical: "unknown","telephone","cellular")
# 10 - day: last contact day of the month (numeric)
#
# 11 - month: last contact month of year (categorical: "jan", "feb", "mar", …, "nov", "dec")
#
# 12 - duration: last contact duration, in seconds (numeric)
#
# # other attributes:
# 13 - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
#
# 14 - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric, -1 means client was not previously contacted)
#
# 15 - previous: number of contacts performed before this campaign and for this client (numeric)
#
# 16 - poutcome: outcome of the previous marketing campaign (categorical: "unknown","other","failure","success")
#
# Output variable (desired target):
#
# 17 - y - has the client subscribed a term deposit? (binary: "yes","no")
#
# Missing Attribute Values: None

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('https://raw.githubusercontent.com/ogut77/DataScience/main/data/Bank.csv',sep = ';')
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 0        unknown    5   may       261         1     -1         0  unknown   no
# 1        unknown    5   may       151         1     -1         0  unknown   no
# 2        unknown    5   may        76         1     -1         0  unknown   no
# 3        unknown    5   may        92         1     -1         0  unknown   no
# 4        unknown    5   may       198         1     -1         0  unknown   no
# ...          ...  ...   ...       ...       ...    ...       ...      ...  ...
# 45206   cellular   17   nov       977         3     -1         0  unknown  yes
# 45207   cellular   17   nov       456         2     -1         0  unknown  yes
# 45208   cellular   17   nov      1127         5    184         3  success  yes
# 45209  telephone   17   nov       508         4     -1         0  unknown   no
# 45210   cellular   17   nov       361         2    188        11    other   no
#
# [45211 rows x 17 columns]

# %%
print(df.shape)
df.info()
df.isnull().sum()
# Out:
# (45211, 17)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
#For object check the data 
for cn in df.columns:
  if(df[cn].dtype==object):
    print(df[cn].value_counts())
    print('-'*40)
# Out:
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: job, dtype: int64
# ----------------------------------------
# married     27214
# single      12790
# divorced     5207
# Name: marital, dtype: int64
# ----------------------------------------
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: education, dtype: int64
# ----------------------------------------
# no     44396
# yes      815
# Name: default, dtype: int64
# ----------------------------------------
# yes    25130
# no     20081
# Name: housing, dtype: int64
# ----------------------------------------
# no     37967
# yes     7244
# Name: loan, dtype: int64
# ----------------------------------------
# cellular     29285
# unknown      13020
# telephone     2906
# Name: contact, dtype: int64
# ----------------------------------------
# may    13766
# jul     6895
# aug     6247
# jun     5341
# nov     3970
# apr     2932
# feb     2649
# jan     1403
# oct      738
# sep      579
# mar      477
# dec      214
# Name: month, dtype: int64
# ----------------------------------------
# unknown    36959
# failure     4901
# other       1840
# success     1511
# Name: poutcome, dtype: int64
# ----------------------------------------
# no     39922
# yes     5289
# Name: y, dtype: int64
# ----------------------------------------

# %%
def Encoder(df):
          from sklearn import preprocessing
          columnsToEncode = list(df.select_dtypes(include=['category','object']))
          le = preprocessing.LabelEncoder()
          for feature in columnsToEncode:
              try:
                  df[feature] = le.fit_transform(df[feature])
              except:
                  print('Error encoding '+feature)
          return df

# %%
df=Encoder(df)
df
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       58    4        1          2        0     2143        1     0        2
# 1       44    9        2          1        0       29        1     0        2
# 2       33    2        1          1        0        2        1     1        2
# 3       47    1        1          3        0     1506        1     0        2
# 4       33   11        2          3        0        1        0     0        2
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 45206   51    9        1          2        0      825        0     0        0
# 45207   71    5        0          0        0     1729        0     0        0
# 45208   72    5        1          1        0     5715        0     0        0
# 45209   57    1        1          1        0      668        0     0        1
# 45210   37    2        1          1        0     2971        0     0        0
#
#        day  month  duration  campaign  pdays  previous  poutcome  y
# 0        5      8       261         1     -1         0         3  0
# 1        5      8       151         1     -1         0         3  0
# 2        5      8        76         1     -1         0         3  0
# 3        5      8        92         1     -1         0         3  0
# 4        5      8       198         1     -1         0         3  0
# ...    ...    ...       ...       ...    ...       ...       ... ..
# 45206   17      9       977         3     -1         0         3  1
# 45207   17      9       456         2     -1         0         3  1
# 45208   17      9      1127         5    184         3         2  1
# 45209   17      9       508         4     -1         0         3  0
# 45210   17      9       361         2    188        11         1  0
#
# [45211 rows x 17 columns]

# %%
y = df['y'] #Output
X = df.drop('y',axis=1)
X
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       58    4        1          2        0     2143        1     0        2
# 1       44    9        2          1        0       29        1     0        2
# 2       33    2        1          1        0        2        1     1        2
# 3       47    1        1          3        0     1506        1     0        2
# 4       33   11        2          3        0        1        0     0        2
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 45206   51    9        1          2        0      825        0     0        0
# 45207   71    5        0          0        0     1729        0     0        0
# 45208   72    5        1          1        0     5715        0     0        0
# 45209   57    1        1          1        0      668        0     0        1
# 45210   37    2        1          1        0     2971        0     0        0
#
#        day  month  duration  campaign  pdays  previous  poutcome
# 0        5      8       261         1     -1         0         3
# 1        5      8       151         1     -1         0         3
# 2        5      8        76         1     -1         0         3
# 3        5      8        92         1     -1         0         3
# 4        5      8       198         1     -1         0         3
# ...    ...    ...       ...       ...    ...       ...       ...
# 45206   17      9       977         3     -1         0         3
# 45207   17      9       456         2     -1         0         3
# 45208   17      9      1127         5    184         3         2
# 45209   17      9       508         4     -1         0         3
# 45210   17      9       361         2    188        11         1
#
# [45211 rows x 16 columns]

# %%
from sklearn.model_selection import  train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=17)

# %%
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
import lightgbm as lgb
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.metrics import accuracy_score, confusion_matrix

# %% [markdown]
# Q1)Using  Random Forest,XGBoost, Light GBM and Gradient Boosting Classifier with default parameters (no parameter specifications except random_state) calculate Accuracy on Test data. Which method gives the best accuracy on test data
#
# **Answer**: Based on accuracy LightGMB gives more better results on test data.

# %%
#Random Forest
forest = RandomForestClassifier(random_state=17 )
forest.fit(X_train, y_train)
forest_pred = forest.predict(X_test)
print(accuracy_score(y_test, forest_pred) )
print(confusion_matrix(y_test, forest_pred)) 

#XGBoost
xgb = XGBClassifier(random_state=17)
xgb.fit(X_train, y_train)
xgb_pred = xgb.predict(X_test)
print(accuracy_score(y_test, xgb_pred))
print(confusion_matrix(y_test, xgb_pred)) 

#LightGBM
lgb = lgb.LGBMClassifier(random_state=17)
lgb.fit(X_train, y_train)
lgb_pred = lgb.predict(X_test)
print(accuracy_score(y_test, lgb_pred))
print(confusion_matrix(y_test, lgb_pred))
      
#GradientBoosting
gbm = GradientBoostingClassifier(random_state=17)
gbm.fit(X_train, y_train)
gbm_pred = gbm.predict(X_test)
print(accuracy_score(y_test, gbm_pred))
print(confusion_matrix(y_test, gbm_pred))
# Out:
# 0.9025037600636999
# [[9635  319]
#  [ 783  566]]
# 0.9043616738918872
# [[9562  392]
#  [ 689  660]]
# 0.9073697248518092
# [[9601  353]
#  [ 694  655]]
# 0.9018844554543042
# [[9657  297]
#  [ 812  537]]

# %% [markdown]
# Q2) Using optuna hyperparmeter optimization technique and 100 trial
#
#  a)find best methods with  parameters  using Cross validation (CV=3) technique for the range of   parameters below. What are the best parameters for the method with highest cross validation accuracy?
#
# "max_depth": range(2, 16), "max_features": range(2, 16)
#
#  b)Evaluate the performance of the  method with highest cross validation accuracy on test data.What is the accuracy value?

# %%
import optuna

import sklearn.ensemble
import sklearn.model_selection
import sklearn.svm

# %%
def objective(trial):
    x, y = X_train,y_train

    classifier_name = trial.suggest_categorical("classifier", ["Random Forest","XGBoost", "LightGBM","GradientBoostingClassifier" ])
    if classifier_name == "Random Forest":
         from sklearn.ensemble import RandomForestClassifier
         max_depth = trial.suggest_int("max_depth", 2,X_train.shape[1])
         max_features = trial.suggest_int("max_features", 2,X_train.shape[1])
         classifier_obj = sklearn.ensemble.RandomForestClassifier(random_state=17,  max_depth=max_depth, max_features=max_features )
        
         

    elif classifier_name == "XGBoost":
         from xgboost import XGBClassifier
         max_depth = trial.suggest_int("max_depth", 2,X_train.shape[1])
         max_features = trial.suggest_int("max_features", 2,X_train.shape[1])
         classifier_obj = XGBClassifier(random_state=17,  max_depth=max_depth, max_features=max_features )
        
         

    elif classifier_name == "LightGBM":
         import lightgbm as lgb
         max_depth = trial.suggest_int("max_depth", 2,X_train.shape[1])
         max_features = trial.suggest_int("max_features", 2,X_train.shape[1])
         classifier_obj = lgb.LGBMClassifier(random_state=17,  max_depth=max_depth, max_features=max_features )
        
       
       
    else:
         max_depth = trial.suggest_int("max_depth", 2,X_train.shape[1])
         max_features = trial.suggest_int("max_features", 2,X_train.shape[1])
         classifier_obj = sklearn.ensemble.GradientBoostingClassifier(random_state=17,  max_depth=max_depth, max_features=max_features )
        
         

    accuracy=sklearn.model_selection.cross_val_score(classifier_obj, x, y, n_jobs=-1, cv=3).mean()
   
    return accuracy

# %%
if __name__ == "__main__":
    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=100)
    print(study.best_trial)
# Out:
# [I 2023-04-07 23:19:30,373] A new study created in memory with name: no-name-ce5ce7c1-e8b9-4437-abec-53d326116eed
# [I 2023-04-07 23:19:42,665] Trial 0 finished with value: 0.9025304013663851 and parameters: {'classifier': 'XGBoost', 'max_depth': 10, 'max_features': 7}. Best is trial 0 with value: 0.9025304013663851.
# [I 2023-04-07 23:19:48,474] Trial 1 finished with value: 0.9062463725361433 and parameters: {'classifier': 'GradientBoostingClassifier', 'max_depth': 5, 'max_features': 12}. Best is trial 1 with value: 0.9062463725361433.
# [I 2023-04-07 23:19:50,803] Trial 2 finished with value: 0.9051257000067515 and parameters: {'classifier': 'XGBoost', 'max_depth': 2, 'max_features': 16}. Best is trial 1 with value: 0.9062463725361433.
# [I 2023-04-07 23:19:55,724] Trial 3 finished with value: 0.905980958884308 and parameters: {'classifier': 'GradientBoostingClassifier', 'max_depth': 6, 'max_features': 7}. Best is trial 1 with value: 0.9062463725361433.
# [I 2023-04-07 23:20:02,560] Trial 4 finished with value: 0.905214119907123 and parameters: {'classifier': 'GradientBoostingClassifier', 'max_depth': 7, 'max_features': 10}. Best is trial 1 with value: 0.9062463725361433.
# [I 2023-04-07 23:20:06,906] Trial 5 finished with value: 0.9060104521893276 and parameters: {'classifier': 'XGBoost', 'max_depth': 7, 'max_features': 3}. Best is trial 1 with value: 0.9062463725361433.
# [I 2023-04-07 23:20:15,073] Trial 6 finished with value: 0.9036510399744319 and parameters: {'classifier': 'GradientBoostingClassifier', 'max_depth': 7, 'max_features': 16}. Best is trial 1 with value: 0.9062463725361433.
# [I 2023-04-07 23:20:22,443] Trial 7 finished with value: 0.9047127937364747 and parameters: {'classifier': 'Random Forest', 'max_depth': 11, 'max_features': 15}. Best is trial 1 with value: 0.9062463725361433.
# [I 2023-04-07 23:20:25,864] Trial 8 finished with value: 0.9072785286197965 and parameters: {'classifier': 'GradientBoostingClassifier', 'max_depth': 7, 'max_features': 5}. Best is trial 8 with value: 0.9072785286197965.
# [I 2023-04-07 23:20:55,455] Trial 9 finished with value: 0.9015572188461003 and parameters: {'classifier': 'GradientBoostingClassifier', 'max_depth': 15, 'max_features': 12}. Best is trial 8 with value: 0.9072785286197965.
# [I 2023-04-07 23:20:57,704] Trial 10 finished with value: 0.9076618893983683 and parameters: {'classifier': 'LightGBM', 'max_depth': 13, 'max_features': 2}. Best is trial 10 with value: 0.9076618893983683.
# [I 2023-04-07 23:20:59,435] Trial 11 finished with value: 0.9068656327868568 and parameters: {'classifier': 'LightGBM', 'max_depth': 14, 'max_features': 2}. Best is trial 10 with value: 0.9076618893983683.
# [I 2023-04-07 23:21:01,397] Trial 12 finished with value: 0.9076618893983683 and parameters: {'classifier': 'LightGBM', 'max_depth': 13, 'max_features': 5}. Best is trial 10 with value: 0.9076618893983683.
# [I 2023-04-07 23:21:03,192] Trial 13 finished with value: 0.9076618893983683 and parameters: {'classifier': 'LightGBM', 'max_depth': 13, 'max_features': 5}. Best is trial 10 with value: 0.9076618893983683.
# [I 2023-04-07 23:21:04,999] Trial 14 finished with value: 0.9073080219248162 and parameters: {'classifier': 'LightGBM', 'max_depth': 16, 'max_features': 4}. Best is trial 10 with value: 0.9076618893983683.
# [I 2023-04-07 23:21:06,716] Trial 15 finished with value: 0.9076618893983683 and parameters: {'classifier': 'LightGBM', 'max_depth': 13, 'max_features': 2}. Best is trial 10 with value: 0.9076618893983683.
# [I 2023-04-07 23:21:07,281] Trial 16 finished with value: 0.9076029654123507 and parameters: {'classifier': 'LightGBM', 'max_depth': 11, 'max_features': 7}. Best is trial 10 with value: 0.9076618893983683.
# [I 2023-04-07 23:21:10,786] Trial 17 finished with value: 0.905862985664229 and parameters: {'classifier': 'Random Forest', 'max_depth': 12, 'max_features': 5}. Best is trial 10 with value: 0.9076618893983683.
# [I 2023-04-07 23:21:11,372] Trial 18 finished with value: 0.9072195759311023 and parameters: {'classifier': 'LightGBM', 'max_depth': 9, 'max_features': 8}. Best is trial 10 with value: 0.9076618893983683.
# [I 2023-04-07 23:21:11,943] Trial 19 finished with value: 0.9073080219248162 and parameters: {'classifier': 'LightGBM', 'max_depth': 16, 'max_features': 4}. Best is trial 10 with value: 0.9076618893983683.
# [I 2023-04-07 23:21
and parameters: {'classifier': 'XGBoost', 'max_depth': 13, 'max_features': 7}. Best is trial 22 with value: 0.9079273656742256.
# FrozenTrial(number=22, state=TrialState.COMPLETE, values=[0.9079273656742256], datetime_start=datetime.datetime(2023, 4, 7, 23, 21, 13, 64532), datetime_complete=datetime.datetime(2023, 4, 7, 23, 21, 13, 646757), params={'classifier': 'LightGBM', 'max_depth': 12, 'max_features': 3}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'classifier': CategoricalDistribution(choices=('Random Forest', 'XGBoost', 'LightGBM', 'GradientBoostingClassifier')), 'max_depth': IntDistribution(high=16, log=False, low=2, step=1), 'max_features': IntDistribution(high=16, log=False, low=2, step=1)}, trial_id=22, value=None)

# %%
study.best_params
# Out:
# {'classifier': 'LightGBM', 'max_depth': 12, 'max_features': 3}

# %%
lgb_opt = lgb.LGBMClassifier(random_state=17, max_depth=12, max_features=3)
lgb_opt.fit(X_train, y_train)
lgb_opt_pred = lgb_opt.predict(X_test)
print(accuracy_score(y_test, lgb_opt_pred))
print(confusion_matrix(y_test, lgb_opt_pred))
# Out:
# [LightGBM] [Warning] Unknown parameter: max_features
# 0.9062195877200743
# [[9588  366]
#  [ 694  655]]

# %%
def objective(trial):
    x, y = X_train,y_train

    param = {
        "objective": "binary",
        "verbosity": -1,
        "boosting_type": "gbdt",
        "max_dept" :trial.suggest_int("max_depth", 2, X_train.shape[1]),
        "max_features" : trial.suggest_int("max_features", 2,X_train.shape[1]),       
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.4, 1.0),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.4, 1.0),
        "bagging_freq": trial.suggest_int("bagging_freq", 1, 7),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
    }
    import lightgbm as lgb
    classifier_obj = lgb.LGBMClassifier(random_state=17,**param)

    accuracy=sklearn.model_selection.cross_val_score(classifier_obj, x, y, n_jobs=-1, cv=3).mean()
   
    return accuracy

# %%
if __name__ == "__main__":
    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=100)
    print(study.best_trial)
# Out:
# [I 2023-04-07 23:31:14,738] A new study created in memory with name: no-name-3dba9a9e-5c75-4f38-9417-2fd7cf870b26
# [I 2023-04-07 23:31:22,074] Trial 0 finished with value: 0.9065412403529848 and parameters: {'max_depth': 11, 'max_features': 5, 'num_leaves': 66, 'feature_fraction': 0.8987123342909368, 'bagging_fraction': 0.9107238274981025, 'bagging_freq': 5, 'min_child_samples': 77}. Best is trial 0 with value: 0.9065412403529848.
# [I 2023-04-07 23:31:25,939] Trial 1 finished with value: 0.9025893618830821 and parameters: {'max_depth': 12, 'max_features': 7, 'num_leaves': 250, 'feature_fraction': 0.9585447565177962, 'bagging_fraction': 0.5224069543498986, 'bagging_freq': 5, 'min_child_samples': 41}. Best is trial 0 with value: 0.9065412403529848.
# [I 2023-04-07 23:31:28,753] Trial 2 finished with value: 0.9052436549614907 and parameters: {'max_depth': 10, 'max_features': 5, 'num_leaves': 7, 'feature_fraction': 0.48890416229613975, 'bagging_fraction': 0.7562856125573092, 'bagging_freq': 7, 'min_child_samples': 57}. Best is trial 0 with value: 0.9065412403529848.
# [I 2023-04-07 23:31:32,578] Trial 3 finished with value: 0.9066887199247547 and parameters: {'max_depth': 4, 'max_features': 13, 'num_leaves': 149, 'feature_fraction': 0.9040386621996584, 'bagging_fraction': 0.9252442218600833, 'bagging_freq': 2, 'min_child_samples': 44}. Best is trial 3 with value: 0.9066887199247547.
# [I 2023-04-07 23:31:35,456] Trial 4 finished with value: 0.9082517737641033 and parameters: {'max_depth': 14, 'max_features': 8, 'num_leaves': 14, 'feature_fraction': 0.9227120912599813, 'bagging_fraction': 0.8549421279269129, 'bagging_freq': 6, 'min_child_samples': 53}. Best is trial 4 with value: 0.9082517737641033.
# [I 2023-04-07 23:31:38,897] Trial 5 finished with value: 0.9048012031995093 and parameters: {'max_depth': 15, 'max_features': 9, 'num_leaves': 226, 'feature_fraction': 0.5476886009778604, 'bagging_fraction': 0.7529383436785465, 'bagging_freq': 1, 'min_child_samples': 74}. Best is trial 4 with value: 0.9082517737641033.
# [I 2023-04-07 23:31:40,443] Trial 6 finished with value: 0.9033856341505992 and parameters: {'max_depth': 9, 'max_features': 6, 'num_leaves': 212, 'feature_fraction': 0.4222753219701702, 'bagging_fraction': 0.5994680973731243, 'bagging_freq': 4, 'min_child_samples': 15}. Best is trial 4 with value: 0.9082517737641033.
# [I 2023-04-07 23:31
 'bagging_freq': 6, 'min_child_samples': 50}. Best is trial 35 with value: 0.9086941550740599.
# [I 2023-04-07 23:32:07,036] Trial 36 finished with value: 0.9053616020882272 and parameters: {'max_depth': 12, 'max_features': 7, 'num_leaves': 78, 'feature_fraction': 0.9060849528624684, 'bagging_fraction': 0.8475303306530131, 'bagging_freq': 7, 'min_child_samples': 51}. Best is trial 35 with value: 0.9086941550740599.
# [I 2023-04-07 23:32:07,617] Trial 37 finished with value: 0.9053321531418898 and parameters: {'max_depth': 9, 'max_features': 4, 'num_leaves': 7, 'feature_fraction': 0.9658860295166136, 'bagging_fraction': 0.9136003548846703, 'bagging_freq': 5, 'min_child_samples': 69}. Best is trial 35 with value: 0.9086941550740599.
# [I 2023-04-07 23:32:08,419] Trial 38 finished with value: 0.9063938129678997 and parameters: {'max_depth': 12, 'max_features': 6, 'num_leaves': 33, 'feature_fraction': 0.8699572567749967, 'bagging_fraction': 0.780173873733415, 'bagging_freq': 6, 'min_child_samples': 81}. Best is trial 35 with value: 0.9086941550740599.
# [I 2023-04-07 23:32:09,113] Trial 39 finished with value: 0.9081338005440243 and parameters: {'max_depth': 15, 'max_features': 5, 'num_leaves': 14, 'feature_fraction': 0.9049186077273184, 'bagging_fraction': 0.9123315296339913, 'bagging_freq': 7, 'min_child_samples': 62}. Best is trial 35 with value: 0.9086941550740599.
# [I 2023-04-07 23:32:10,540] Trial 40 finished with value: 0.9058629621802207 and parameters: {'max_depth': 15, 'max_features': 8, 'num_leaves': 142, 'feature_fraction': 0.8293650103510352, 'bagging_fraction': 0.8708175635626106, 'bagging_freq': 4, 'min_child_samples': 47}. Best is trial 35 with value: 0.9086941550740599.
# [I 2023-04-07 23:32:11,137] Trial 41 finished with value: 0.9065707571420126 and parameters: {'max_depth': 15, 'max_features': 5, 'num_leaves': 11, 'feature_fraction': 0.9046248141958292, 'bagging_fraction': 0.9274075833378582, 'bagging_freq': 7, 'min_child_samples': 61}. Best is trial 35 with value: 0.9086941550740599.
# [I 2023-04-07 23:32:11,987] Trial 42 finished with value: 0.9065117470479649 and parameters: {'max_depth': 13, 'max_features': 4, 'num_leaves': 47, 'feature_fraction': 0.999522770103421, 'bagging_fraction': 0.910127861771887, 'bagging_freq': 7, 'min_child_samples': 39}. Best is trial 35 with value: 0.9086941550740599.
# [I 2023-04-07 23:32:12,618] Trial 43 finished with value: 0.9074849739269321 and parameters: {'max_depth': 16, 'max_features': 3, 'num_leaves': 13, 'feature_fraction': 0.8982349723528386, 'bagging_fraction': 0.8965652099387033, 'bagging_freq': 6, 'min_child_samples': 75}. Best is trial 35 with value: 0.9086941550740599.
# [I 2023-04-07 23:32:14,470] Trial 44 finished with value: 0.9051256608667376 and parameters: {'max_depth': 15, 'max_features': 6, 'num_leaves': 237, 'feature_fraction': 0.8627883111034526, 'bagging_fraction': 0.9414905723998189, 'bagging_freq': 7, 'min_child_samples': 56}. Best is trial 35 with value: 0.9086941550740599.
# [I 2023-04-07 23:32:14,882] Trial 45 finished with value: 0.8922378328426976 and parameters: {'max_depth': 12, 'max_features': 7, 'num_leaves': 2, 'feature_fraction': 0.9616617652902183, 'bagging_fraction': 0.7240671569542526, 'bagging_freq': 6, 'min_child_samples': 64}. Best is trial 35 with value: 0.9086941550740599.
# [I 2023-04-07 23:32:16,582] Trial 46 finished with value: 0.905273132610505 and parameters: {'max_depth': 14, 'max_features': 8, 'num_leaves': 199, 'feature_fraction': 0.8078964153926653, 'bagging_fraction': 0.8253357003967112, 'bagging_freq': 7, 'min_child_samples': 69}. Best is trial 35 with value: 0.9086941550740599.
# [I 2023-04-07 23:32:17,403] Trial 47 finished with value: 0.9071310934067086 and parameters: {'max_depth': 13, 'max_features': 9, 'num_leaves': 34, 'feature_fraction': 0.9625140001849066, 'bagging_fraction': 0.7870905811615235, 'bagging_freq': 6, 'min_child_samples': 80}. Best is trial 35 with value: 0.9086941550740599.
# [I 2023-04-07 23:32:18,326] Trial 48 finished with value: 0.9063643118348771 and parameters: {'max_depth': 8, 'max_features': 5, 'num_leaves': 59, 'feature_fraction': 0.91425505884536, 'bagging_fraction': 0.8640551892172825, 'bagging_freq': 7, 'min_child_samples': 41}. Best is trial 35 with value: 0.9086941550740599.
# [I 2023-04-07 23:32:19,182] Trial 49 finished with value: 0.9079863522842652 and parameters: {'max_depth': 10, 'max_features': 3, 'num_leaves': 40, 'feature_fraction': 0.8811017095253971, 'bagging_fraction': 0.9201245885781082, 'bagging_freq': 4, 'min_child_samples': 66}. Best is trial 35 with value: 0.9086941550740599.
# [I 2023-04-07 23:32:20,068] Trial 50 finished with value: 0.9076619076637081 and parameters: {'max_depth': 10, 'max_features': 3, 'num_leaves': 43, 'feature_fraction': 0.8413966161717802, 'bagging_fraction': 0.9223220642150896, 'bagging_freq': 4, 'min_child_samples': 67}. Best is trial 35 with value: 0.9086941550740599.
# [I 2023-04-07 23:32:20,746] Trial 51 finished with value: 0.9073080245341506 and parameters: {'max_depth': 11, 'max_features': 4, 'num_leaves': 15, 'feature_fraction': 0.8704517710186833, 'bagging_fraction': 0.9717482128606165, 'bagging_freq': 3, 'min_child_samples': 60}. Best is trial 35 with value: 0.9086941550740599.
# [I 2023-04-07 23:32:21,538] Trial 52 finished with value: 0.9076324065306856 and parameters: {'max_depth': 10, 'max_features': 2, 'num_leaves': 30, 'feature_fraction': 0.9244928194793259, 'bagging_fraction': 0.9359234434180972, 'bagging_freq': 3, 'min_child_samples': 47}. Best is trial 35 with value: 0.9086941550740599.
# [I 2023-04-07 23:32:22,170] Trial 53 finished with value: 0.9072785181824594 and parameters: {'max_depth': 9, 'max_features': 6, 'num_leaves': 13, 'feature_fraction': 0.8885941206188863, 'bagging_fraction': 0.9085974340302772, 'bagging_freq': 5, 'min_child_samples': 73}. Best is trial 35 with value: 0.9086941550740599.
# [I 2023-04-07 23:32:23,018] Trial 54 finished with value: 0.9069836660216235 and parameters: {'max_depth': 12, 'max_features': 3, 'num_leaves': 42, 'feature_fraction': 0.9721026996496216, 'bagging_fraction': 0.8458273998260907, 'bagging_freq': 4, 'min_child_samples': 55}. Best is trial 35 with value: 0.9086941550740599.
# [I 2023-04-07 23:32:24,969] Trial 55 finished with value: 0.9042704359105264 and parameters: {'max_depth': 16, 'max_features': 7, 'num_leaves': 256, 'feature_fraction': 0.9495580983028121, 'bagging_fraction': 0.9773297498975019, 'bagging_freq': 4, 'min_child_samples': 59}. Best is trial 35 with value: 0.9086941550740599.
# [I 2023-04-07 23:32:25,745] Trial 56 finished with value: 0.9063937764372202 and parameters: {'max_depth': 2, 'max_features': 9, 'num_leaves': 30, 'feature_fraction': 0.9222946381405132, 'bagging_fraction': 0.9432576542888791, 'bagging_freq': 6, 'min_child_samples': 66}. Best is trial 35 with value: 0.9086941550740599.
# [I 2023-04-07 23:32:26,783] Trial 57 finished with value: 0.9062168974964632 and parameters: {'max_depth': 14, 'max_features': 2, 'num_leaves': 114, 'feature_fraction': 0.8519053687209528, 'bagging_fraction': 0.8904992269983597, 'bagging_freq': 1, 'min_child_samples': 88}. Best is trial 35 with value: 0.9086941550740599.
# [I 2023-04-07 23:32:27,602] Trial 58 finished with value: 0.9086941681207312 and parameters: {'max_depth': 13, 'max_features': 10, 'num_leaves': 19, 'feature_fraction': 0.893143316904488, 'bagging_fraction': 0.9819184258392739, 'bagging_freq': 6, 'min_child_samples': 72}. Best is trial 58 with value: 0.9086941681207312.
# [I 2023-04-07 23:32:28,721] Trial 59 finished with value: 0.9065707206113331 and parameters: {'max_depth': 13, 'max_features': 10, 'num_leaves': 71, 'feature_fraction': 0.9408576115078422, 'bagging_fraction': 0.9749280737715117, 'bagging_freq': 5, 'min_child_samples': 95}. Best is trial 58 with value: 0.9086941681207312.
# [I 2023-04-07 23:32:29,720] Trial 60 finished with value: 0.9072490666267877 and parameters: {'max_depth': 5, 'max_features': 9, 'num_leaves': 49, 'feature_fraction': 0.9769231843000631, 'bagging_fraction': 0.9811972350752235, 'bagging_freq': 5, 'min_child_samples': 78}. Best is trial 58 with value: 0.9086941681207312.
# [I 2023-04-07 23:32:30,476] Trial 61 finished with value: 0.9074849634895951 and parameters: {'max_depth': 13, 'max_features': 4, 'num_leaves': 23, 'feature_fraction': 0.8781625952779637, 'bagging_fraction': 0.9494275411855599, 'bagging_freq': 6, 'min_child_samples': 71}. Best is trial 58 with value: 0.9086941681207312.
# [I 2023-04-07 23:32:31,047] Trial 62 finished with value: 0.9063938521079132 and parameters: {'max_depth': 12, 'max_features': 11, 'num_leaves': 7, 'feature_fraction': 0.9085817069471177, 'bagging_fraction': 0.9264499708033339, 'bagging_freq': 6, 'min_child_samples': 53}. Best is trial 58 with value: 0.9086941681207312.
# [I 2023-04-07 23:32:31,762] Trial 63 finished with value: 0.9071310699227003 and parameters: {'max_depth': 14, 'max_features': 5, 'num_leaves': 18, 'feature_fraction': 0.891608936447806, 'bagging_fraction': 0.9510096434823733, 'bagging_freq': 7, 'min_child_samples': 84}. Best is trial 58 with value: 0.9086941681207312.
# [I 2023-04-07 23:32:32,631] Trial 64 finished with value: 0.9065707075646618 and parameters: {'max_depth': 14, 'max_features': 13, 'num_leaves': 40, 'feature_fraction': 0.9356527473692975, 'bagging_fraction': 0.8751511651462012, 'bagging_freq': 6, 'min_child_samples': 64}. Best is trial 58 with value: 0.9086941681207312.
# [I 2023-04-07 23:32:33,407] Trial 65 finished with value: 0.9078389014151719 and parameters: {'max_depth': 11, 'max_features': 8, 'num_leaves': 28, 'feature_fraction': 0.8599715763976676, 'bagging_fraction': 0.9858810851372417, 'bagging_freq': 7, 'min_child_samples': 58}. Best is trial 58 with value: 0.9086941681207312.
# [I 2023-04-07 23:32:34,406] Trial 66 finished with value: 0.9071311351560566 and parameters: {'max_depth': 15, 'max_features': 10, 'num_leaves': 59, 'feature_fraction': 0.9155570955544242, 'bagging_fraction': 0.9577541534853146, 'bagging_freq': 5, 'min_child_samples': 74}. Best is trial 58 with value: 0.9086941681207312.
# [I 2023-04-07 23:32:35,038] Trial 67 finished with value: 0.9065412612276588 and parameters: {'max_depth': 13, 'max_features': 15, 'num_leaves': 11, 'feature_fraction': 0.8143408900796247, 'bagging_fraction': 0.9083243545224154, 'bagging_freq': 6, 'min_child_samples': 50}. Best is trial 58 with value: 0.9086941681207312.
# [I 2023-04-07 23:32:36,100] Trial 68 finished with value: 0.9045653350393786 and parameters: {'max_depth': 8, 'max_features': 7, 'num_leaves': 94, 'feature_fraction': 0.8848519719856403, 'bagging_fraction': 0.9962952894139484, 'bagging_freq': 7, 'min_child_samples': 28}. Best is trial 58 with value: 0.9086941681207312.
# [I 2023-04-07 23:32:36,526] Trial 69 finished with value: 0.8919724009255225 and parameters: {'max_depth': 12, 'max_features': 16, 'num_leaves': 2, 'feature_fraction': 0.7834984831531078, 'bagging_fraction': 0.8881158374972771, 'bagging_freq': 6, 'min_child_samples': 45}. Best is trial 58 with value: 0.9086941681207312.
# [I 2023-04-07 23:32:37,445] Trial 70 finished with value: 0.9082222569750753 and parameters: {'max_depth': 16, 'max_features': 3, 'num_leaves': 21, 'feature_fraction': 0.8478603449225677, 'bagging_fraction': 0.9268468618130922, 'bagging_freq': 2, 'min_child_samples': 53}. Best is trial 58 with value: 0.9086941681207312.
# [I 2023-04-07 23:32:38,200] Trial 71 finished with value: 0.9088121335128075 and parameters: {'max_depth': 16, 'max_features': 3, 'num_leaves': 19, 'feature_fraction': 0.8469305008585541, 'bagging_fraction': 0.9305545387184032, 'bagging_freq': 2, 'min_child_samples': 52}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:32:39,084] Trial 72 finished with value: 0.9072785781971472 and parameters: {'max_depth': 16, 'max_features': 3, 'num_leaves': 36, 'feature_fraction': 0.8358986306788715, 'bagging_fraction': 0.9375697101103356, 'bagging_freq': 2, 'min_child_samples': 53}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:32:39,855] Trial 73 finished with value: 0.9078978619318688 and parameters: {'max_depth': 15, 'max_features': 2, 'num_leaves': 23, 'feature_fraction': 0.931271401565467, 'bagging_fraction': 0.9142118152162033, 'bagging_freq': 2, 'min_child_samples': 48}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:32:40,662] Trial 74 finished with value: 0.9079273500182202 and parameters: {'max_depth': 16, 'max_features': 3, 'num_leaves': 28, 'feature_fraction': 0.8541716551659111, 'bagging_fraction': 0.968384809961456, 'bagging_freq': 2, 'min_child_samples': 42}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:32:41,212] Trial 75 finished with value: 0.9063053617555171 and parameters: {'max_depth': 16, 'max_features': 2, 'num_leaves': 9, 'feature_fraction': 0.8733234306208866, 'bagging_fraction': 0.9260934240144665, 'bagging_freq': 1, 'min_child_samples': 56}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:32:42,068] Trial 76 finished with value: 0.907219573321768 and parameters: {'max_depth': 15, 'max_features': 6, 'num_leaves': 37, 'feature_fraction': 0.950772125699379, 'bagging_fraction': 0.8987722512756658, 'bagging_freq': 3, 'min_child_samples': 63}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:32:42,819] Trial 77 finished with value: 0.9085171795879359 and parameters: {'max_depth': 15, 'max_features': 3, 'num_leaves': 20, 'feature_fraction': 0.9024968584103027, 'bagging_fraction': 0.8816582779773218, 'bagging_freq': 2, 'min_child_samples': 67}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:32:43,578] Trial 78 finished with value: 0.907308019315482 and parameters: {'max_depth': 15, 'max_features': 5, 'num_leaves': 21, 'feature_fraction': 0.9137333274572575, 'bagging_fraction': 0.8651165663260374, 'bagging_freq': 2, 'min_child_samples': 39}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:32:44,333] Trial 79 finished with value: 0.9085761609793069 and parameters: {'max_depth': 16, 'max_features': 4, 'num_leaves': 16, 'feature_fraction': 0.9849776315732688, 'bagging_fraction': 0.8846557888298884, 'bagging_freq': 2, 'min_child_samples': 52}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:32:45,264] Trial 80 finished with value: 0.9067771398251262 and parameters: {'max_depth': 16, 'max_features': 4, 'num_leaves': 52, 'feature_fraction': 0.9873064416598105, 'bagging_fraction': 0.8548626396365848, 'bagging_freq': 2, 'min_child_samples': 37}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:32:46,018] Trial 81 finished with value: 0.908251771154769 and parameters: {'max_depth': 14, 'max_features': 4, 'num_leaves': 16, 'feature_fraction': 0.9600880292557821, 'bagging_fraction': 0.8800119252347335, 'bagging_freq': 2, 'min_child_samples': 52}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:32:46,741] Trial 82 finished with value: 0.9080158299332796 and parameters: {'max_depth': 14, 'max_features': 4, 'num_leaves': 17, 'feature_fraction': 0.9744162626686736, 'bagging_fraction': 0.8794177596038786, 'bagging_freq': 2, 'min_child_samples': 44}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:32:48,069] Trial 83 finished with value: 0.9045653272113761 and parameters: {'max_depth': 15, 'max_features': 12, 'num_leaves': 164, 'feature_fraction': 0.9990826707951677, 'bagging_fraction': 0.8365270984415273, 'bagging_freq': 1, 'min_child_samples': 51}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:32:48,684] Trial 84 finished with value: 0.9054500872219551 and parameters: {'max_depth': 16, 'max_features': 3, 'num_leaves': 7, 'feature_fraction': 0.9564222871491831, 'bagging_fraction': 0.8802509531986421, 'bagging_freq': 2, 'min_child_samples': 55}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:32:49,493] Trial 85 finished with value: 0.9083106951407866 and parameters: {'max_depth': 14, 'max_features': 2, 'num_leaves': 26, 'feature_fraction': 0.9341723263557891, 'bagging_fraction': 0.8957608008741937, 'bagging_freq': 2, 'min_child_samples': 19}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:32:50,762] Trial 86 finished with value: 0.9035920977230746 and parameters: {'max_depth': 14, 'max_features': 2, 'num_leaves': 133, 'feature_fraction': 0.9433664225806815, 'bagging_fraction': 0.8957316752686093, 'bagging_freq': 2, 'min_child_samples': 18}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:32:51,567] Trial 87 finished with value: 0.9084581747125565 and parameters: {'max_depth': 16, 'max_features': 3, 'num_leaves': 31, 'feature_fraction': 0.9848219825911053, 'bagging_fraction': 0.8269877996178913, 'bagging_freq': 2, 'min_child_samples': 48}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:32:52,357] Trial 88 finished with value: 0.9074849921922717 and parameters: {'max_depth': 15, 'max_features': 2, 'num_leaves': 30, 'feature_fraction': 0.9838179848031597, 'bagging_fraction': 0.8598956600752821, 'bagging_freq': 3, 'min_child_samples': 48}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:32:52,877] Trial 89 finished with value: 0.905862988273563 and parameters: {'max_depth': 14, 'max_features': 3, 'num_leaves': 7, 'feature_fraction': 0.9701959171779277, 'bagging_fraction': 0.805170130484549, 'bagging_freq': 1, 'min_child_samples': 50}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:32:53,584] Trial 90 finished with value: 0.9081633199423865 and parameters: {'max_depth': 16, 'max_features': 10, 'num_leaves': 15, 'feature_fraction': 0.9310158355904095, 'bagging_fraction': 0.8484201934942668, 'bagging_freq': 2, 'min_child_samples': 58}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:32:54,359] Trial 91 finished with value: 0.9082812409757807 and parameters: {'max_depth': 16, 'max_features': 2, 'num_leaves': 25, 'feature_fraction': 0.9596321878018984, 'bagging_fraction': 0.8365089695301885, 'bagging_freq': 2, 'min_child_samples': 53}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:32:55,205] Trial 92 finished with value: 0.9066886860034096 and parameters: {'max_depth': 15, 'max_features': 2, 'num_leaves': 33, 'feature_fraction': 0.9578202836413499, 'bagging_fraction': 0.8303687776543107, 'bagging_freq': 2, 'min_child_samples': 45}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:32:56,092] Trial 93 finished with value: 0.9070425978356438 and parameters: {'max_depth': 16, 'max_features': 11, 'num_leaves': 45, 'feature_fraction': 0.9904229144867432, 'bagging_fraction': 0.8699106884327843, 'bagging_freq': 2, 'min_child_samples': 47}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:32:56,833] Trial 94 finished with value: 0.9081042941923333 and parameters: {'max_depth': 15, 'max_features': 3, 'num_leaves': 26, 'feature_fraction': 0.9609057702317091, 'bagging_fraction': 0.8426866445142344, 'bagging_freq': 3, 'min_child_samples': 32}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:32:57,317] Trial 95 finished with value: 0.891471030396192 and parameters: {'max_depth': 14, 'max_features': 2, 'num_leaves': 2, 'feature_fraction': 0.9423513332358284, 'bagging_fraction': 0.809231911048772, 'bagging_freq': 2, 'min_child_samples': 52}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:32:57,849] Trial 96 finished with value: 0.9067181975737689 and parameters: {'max_depth': 13, 'max_features': 4, 'num_leaves': 10, 'feature_fraction': 0.902164759081641, 'bagging_fraction': 0.82567830582407, 'bagging_freq': 1, 'min_child_samples': 40}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:32:58,563] Trial 97 finished with value: 0.908812096982128 and parameters: {'max_depth': 16, 'max_features': 8, 'num_leaves': 18, 'feature_fraction': 0.9204816727814467, 'bagging_fraction': 0.8839227601353141, 'bagging_freq': 3, 'min_child_samples': 24}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:32:59,355] Trial 98 finished with value: 0.9068361577471767 and parameters: {'max_depth': 16, 'max_features': 8, 'num_leaves': 26, 'feature_fraction': 0.9252080692986221, 'bagging_fraction': 0.855696208493256, 'bagging_freq': 3, 'min_child_samples': 22}. Best is trial 71 with value: 0.9088121335128075.
# [I 2023-04-07 23:33:00,160] Trial 99 finished with value: 0.9069246402715704 and parameters: {'max_depth': 16, 'max_features': 9, 'num_leaves': 35, 'feature_fraction': 0.8965598992690128, 'bagging_fraction': 0.9020120097656713, 'bagging_freq': 3, 'min_child_samples': 12}. Best is trial 71 with value: 0.9088121335128075.
# FrozenTrial(number=71, state=TrialState.COMPLETE, values=[0.9088121335128075], datetime_start=datetime.datetime(2023, 4, 7, 23, 32, 37, 447961), datetime_complete=datetime.datetime(2023, 4, 7, 23, 32, 38, 200227), params={'max_depth': 16, 'max_features': 3, 'num_leaves': 19, 'feature_fraction': 0.8469305008585541, 'bagging_fraction': 0.9305545387184032, 'bagging_freq': 2, 'min_child_samples': 52}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=16, log=False, low=2, step=1), 'max_features': IntDistribution(high=16, log=False, low=2, step=1), 'num_leaves': IntDistribution(high=256, log=False, low=2, step=1), 'feature_fraction': FloatDistribution(high=1.0, log=False, low=0.4, step=None), 'bagging_fraction': FloatDistribution(high=1.0, log=False, low=0.4, step=None), 'bagging_freq': IntDistribution(high=7, log=False, low=1, step=1), 'min_child_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=71, value=None)

# %%
 print(study.best_params)
# Out:
# {'max_depth': 16, 'max_features': 3, 'num_leaves': 19, 'feature_fraction': 0.8469305008585541, 'bagging_fraction': 0.9305545387184032, 'bagging_freq': 2, 'min_child_samples': 52}

# %%
model = lgb.LGBMClassifier(random_state=17,**study.best_params)
model.fit(X_train, y_train)
# make predictions for test data
xgb_pred = model.predict(X_test)
accuracy_score(y_test, xgb_pred)
# Out:
# [LightGBM] [Warning] Unknown parameter: max_features
# [LightGBM] [Warning] feature_fraction is set=0.8469305008585541, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8469305008585541
# [LightGBM] [Warning] bagging_fraction is set=0.9305545387184032, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9305545387184032
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# 0.9065734760683004

# %% [markdown]
# For Q3 and Q4 ,use the following data.

# %%
dr=pd.read_csv('https://raw.githubusercontent.com/ogut77/DataScience/main/data/diamond.csv')
dr
# Out:
#       Carat Weight              Cut Color Clarity Polish Symmetry Report  \
# 0             1.10            Ideal     H     SI1     VG       EX    GIA
# 1             0.83            Ideal     H     VS1     ID       ID   AGSL
# 2             0.85            Ideal     H     SI1     EX       EX    GIA
# 3             0.91            Ideal     E     SI1     VG       VG    GIA
# 4             0.83            Ideal     G     SI1     EX       EX    GIA
# ...            ...              ...   ...     ...    ...      ...    ...
# 5995          1.03            Ideal     D     SI1     EX       EX    GIA
# 5996          1.00        Very Good     D     SI1     VG       VG    GIA
# 5997          1.02            Ideal     D     SI1     EX       EX    GIA
# 5998          1.27  Signature-Ideal     G     VS1     EX       EX    GIA
# 5999          2.19            Ideal     E     VS1     EX       EX    GIA
#
#       Price
# 0      5169
# 1      3470
# 2      3183
# 3      4370
# 4      3171
# ...     ...
# 5995   6250
# 5996   5328
# 5997   6157
# 5998  11206
# 5999  30507
#
# [6000 rows x 8 columns]

# %%
def Encoder(df):
          from sklearn import preprocessing
          columnsToEncode = list(df.select_dtypes(include=['category','object']))
          le = preprocessing.LabelEncoder()
          for feature in columnsToEncode:
              try:
                  df[feature] = le.fit_transform(df[feature])
              except:
                  print('Error encoding '+feature)
          return df

# %%
dr=Encoder(dr)
dr
# Out:
#       Carat Weight  Cut  Color  Clarity  Polish  Symmetry  Report  Price
# 0             1.10    2      4        2       3         0       1   5169
# 1             0.83    2      4        3       2         2       0   3470
# 2             0.85    2      4        2       0         0       1   3183
# 3             0.91    2      1        2       3         3       1   4370
# 4             0.83    2      3        2       0         0       1   3171
# ...            ...  ...    ...      ...     ...       ...     ...    ...
# 5995          1.03    2      0        2       0         0       1   6250
# 5996          1.00    4      0        2       3         3       1   5328
# 5997          1.02    2      0        2       0         0       1   6157
# 5998          1.27    3      3        3       0         0       1  11206
# 5999          2.19    2      1        3       0         0       1  30507
#
# [6000 rows x 8 columns]

# %%
y = dr['Price'] #Output
X = dr.drop('Price',axis=1)
X
# Out:
#       Carat Weight  Cut  Color  Clarity  Polish  Symmetry  Report
# 0             1.10    2      4        2       3         0       1
# 1             0.83    2      4        3       2         2       0
# 2             0.85    2      4        2       0         0       1
# 3             0.91    2      1        2       3         3       1
# 4             0.83    2      3        2       0         0       1
# ...            ...  ...    ...      ...     ...       ...     ...
# 5995          1.03    2      0        2       0         0       1
# 5996          1.00    4      0        2       3         3       1
# 5997          1.02    2      0        2       0         0       1
# 5998          1.27    3      3        3       0         0       1
# 5999          2.19    2      1        3       0         0       1
#
# [6000 rows x 7 columns]

# %%
from sklearn.model_selection import  train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=17)

# %% [markdown]
# Q3)Using Linear Regression,Decison Tree Random Forest,XGBoost, Light GBM and Gradient Boosting Classifier with default parameters (no parameter specifications except random_state) calculate R2 statistics on test data. Which method gives the best accuracy on test data

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
import lightgbm as lgb
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score

# %%
#Linear Regression
lr = LinearRegression()
lr.fit(X_train,y_train)
lr_pred = lr.predict(X_test)
print(r2_score(y_test, lr_pred))

#DecisionTree
tree = DecisionTreeRegressor(random_state=17)
tree.fit(X_train,y_train)
tree_pred = tree.predict(X_test)
print(r2_score(y_test, tree_pred))

#RandomForestRegressor
forest = RandomForestRegressor(random_state=17 )
forest.fit(X_train, y_train)
forest_pred = forest.predict(X_test)
print(r2_score(y_test, forest_pred))


#XGBoost
xgb = XGBRegressor(random_state=17)
xgb.fit(X_train, y_train)
xbg_pred = xgb.predict(X_test)
print(r2_score(y_test, xgb_pred))

#LightGBM
lgr = lgb.LGBMRegressor(random_state=17)
lgr.fit(X_train, y_train)
lgr_pred = lgr.predict(X_test)
print(r2_score(y_test, lgr_pred))

      
#GradientBoosting
gbr = GradientBoostingRegressor(random_state=17)
gbr.fit(X_train, y_train)
gbr_pred = gbr.predict(X_test)
print(r2_score(y_test, xgr_pred))
# Out:
# 0.823384582969696
# 0.95923297527452
# 0.9799660276771226
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [42], in <cell line: 22>()
#      20 #XGBoost
#      21 xgb = XGBRegressor(random_state=17)
# ---> 22 xgb.fit(X_train, y_train)
#      23 xbg_pred = xgb.predict(X_test)
#      24 print(r2_score(y_test, xgb_pred))
#
# File ~\anaconda3\lib\site-packages\xgboost\core.py:532, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     530 for k, arg in zip(sig.parameters, args):
#     531     kwargs[k] = arg
# --> 532 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\xgboost\sklearn.py:961, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#     956     obj = None
#     958 model, metric, params, early_stopping_rounds, callbacks = self._configure_fit(
#     959     xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#     960 )
# --> 961 self._Booster = train(
#     962     params,
#     963     train_dmatrix,
#     964     self.get_num_boosting_rounds(),
#     965     evals=evals,
#     966     early_stopping_rounds=early_stopping_rounds,
#     967     evals_result=evals_result,
#     968     obj=obj,
#     969     custom_metric=metric,
#     970     verbose_eval=verbose,
#     971     xgb_model=model,
#     972     callbacks=callbacks,
#     973 )
#     975 self._set_evaluation_result(evals_result)
#     976 return self
#
# File ~\anaconda3\lib\site-packages\xgboost\core.py:532, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     530 for k, arg in zip(sig.parameters, args):
#     531     kwargs[k] = arg
# --> 532 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\xgboost\training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, i, obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File ~\anaconda3\lib\site-packages\xgboost\core.py:1733, in Booster.update(self, dtrain, iteration, fobj)
#    1730 self._validate_features(dtrain)
#    1732 if fobj is None:
# -> 1733     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1734                                             ctypes.c_int(iteration),
#    1735                                             dtrain.handle))
#    1736 else:
#    1737     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %% [markdown]
# Q4) Using optuna hyperparmeter optimization technique (100 trial)  with Random Forest,XGBoost, Light GBM and Gradient Boosting Regressor
#
# a)find best methods with  parameters  using Cross validation (CV=3) technique for the range of   parameters below. What are the best parameters for the method with highest cross validation R2?
#
# "max_depth": range(2, 7), "max_features": range(2, 7)
#
#  b)Evaluate the performance of the  method with highest cross validation R2 on test data. What is the R2 value?

# %%
def objective(trial):
    x, y = X_train,y_train

    regressor_name = trial.suggest_categorical("regressor", ["GradientBoosting", "XGBoost","LightGBM","RandomForest"])
    if regressor_name == "GradientBoosting":
         max_depth = trial.suggest_int("max_depth", 2,16)
         max_features = trial.suggest_int("max_features", 2,X_train.shape[1])
         regressor_obj = sklearn.ensemble.GradientBoostingRegressor(random_state=17,  max_depth=max_depth, max_features=max_features )
    
    elif regressor_name == "XGBoost":
         from xgboost import XGBRegressor
         max_depth = trial.suggest_int("max_depth", 2,X_train.shape[1])
         max_features = trial.suggest_int("max_features", 2,X_train.shape[1])
         regressor_obj = XGBRegressor(random_state=17,  max_depth=max_depth, max_features=max_features )
        
    if regressor_name == "Random Forest":
         from sklearn.ensemble import RandomForestRegressor
         max_depth = trial.suggest_int("max_depth", 2,X_train.shape[1])
         max_features = trial.suggest_int("max_features", 2,X_train.shape[1])
         classifier_obj = sklearn.ensemble.RandomForestRegressor(random_state=17,  max_depth=max_depth, max_features=max_features )    

    elif regressor_name == "LightGBM":
         import lightgbm as lgb
         max_depth = trial.suggest_int("max_depth", 2,X_train.shape[1])
         max_features = trial.suggest_int("max_features", 2,X_train.shape[1])
         regressor_obj = lgb.LGBMRegressor(random_state=17,  max_depth=max_depth, max_features=max_features )
        
       
   
    else:
         max_depth = trial.suggest_int("max_depth", 2,16)
         max_features = trial.suggest_int("max_features", 2,X_train.shape[1])
         regressor_obj = sklearn.ensemble.RandomForestRegressor(random_state=17,  max_depth=max_depth, max_features=max_features )

     

    r2=sklearn.model_selection.cross_val_score(regressor_obj, x, y, n_jobs=-1, cv=3).mean()
   
    return r2


if __name__ == "__main__":
    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=20)
    print(study.best_trial)
# Out:
# [I 2023-04-07 23:54:40,581] A new study created in memory with name: no-name-881b91ec-5696-46a4-93f3-d84665000aee
# [I 2023-04-07 23:54:46,388] Trial 0 finished with value: 0.9808563605709252 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 14, 'max_features': 6}. Best is trial 0 with value: 0.9808563605709252.
# [I 2023-04-07 23:54:47,920] Trial 1 finished with value: 0.9743371815982403 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 8, 'max_features': 4}. Best is trial 0 with value: 0.9808563605709252.
# C:\Users\abdul\anaconda3\lib\site-packages\optuna\trial\_trial.py:681: RuntimeWarning: Inconsistent parameter values for distribution with name "max_depth"! This might be a configuration mistake. Optuna allows to call the same distribution with the same name more than once in a trial. When the parameter values are inconsistent optuna only uses the values of the first call and ignores all following. Using these values: {'log': False, 'step': 1, 'low': 2, 'high': 7}
#   warnings.warn(
# [I 2023-04-07 23:54:49,557] Trial 2 finished with value: 0.9407314378830723 and parameters: {'regressor': 'XGBoost', 'max_depth': 5, 'max_features': 4}. Best is trial 0 with value: 0.9808563605709252.
# [I 2023-04-07 23:54:51,129] Trial 3 finished with value: 0.7711764795750011 and parameters: {'regressor': 'XGBoost', 'max_depth': 2, 'max_features': 7}. Best is trial 0 with value: 0.9808563605709252.
# [I 2023-04-07 23:54:53,486] Trial 4 finished with value: 0.9706874365810324 and parameters: {'regressor': 'LightGBM', 'max_depth': 3, 'max_features': 5}. Best is trial 0 with value: 0.9808563605709252.
# [I 2023-04-07 23:54:55,019] Trial 5 finished with value: 0.9375844290578602 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 6, 'max_features': 3}. Best is trial 0 with value: 0.9808563605709252.
# [I 2023-04-07 23:54:56,289] Trial 6 finished with value: 0.9758296442252078 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 3}. Best is trial 0 with value: 0.9808563605709252.
# [I 2023-04-07 23:54:57,524] Trial 7 finished with value: 0.9758941121368242 and parameters: {'regressor': 'LightGBM', 'max_depth': 6, 'max_features': 4}. Best is trial 0 with value: 0.9808563605709252.
# [I 2023-04-07 23:54:57,904] Trial 8 finished with value: 0.9585267783923223 and parameters: {'regressor': 'RandomForest', 'max_depth': 13, 'max_features': 2}. Best is trial 0 with value: 0.9808563605709252.
# [I 2023-04-07 23:54:58,231] Trial 9 finished with value: 0.7739509743309535 and parameters: {'regressor': 'RandomForest', 'max_depth': 2, 'max_features': 5}. Best is trial 0 with value: 0.9808563605709252.
# [W 2023-04-07 23:54:59,526] Trial 10 failed with parameters: {'regressor': 'GradientBoosting', 'max_depth': 16, 'max_features': 7} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "C:\Users\abdul\anaconda3\lib\site-packages\optuna\study\_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#   File "C:\Users\abdul\AppData\Local\Temp\ipykernel_23580\2996191720.py", line 37, in objective
#     r2=sklearn.model_selection.cross_val_score(regressor_obj, x, y, n_jobs=-1, cv=3).mean()
#   File "C:\Users\abdul\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 515, in cross_val_score
#     cv_results = cross_validate(
#   File "C:\Users\abdul\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 266, in cross_validate
#     results = parallel(
#   File "C:\Users\abdul\anaconda3\lib\site-packages\joblib\parallel.py", line 1056, in __call__
#     self.retrieve()
#   File "C:\Users\abdul\anaconda3\lib\site-packages\joblib\parallel.py", line 935, in retrieve
#     self._output.extend(job.get(timeout=self.timeout))
#   File "C:\Users\abdul\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 542, in wrap_future_result
#     return future.result(timeout=timeout)
#   File "C:\Users\abdul\anaconda3\lib\concurrent\futures\_base.py", line 441, in result
#     self._condition.wait(timeout)
#   File "C:\Users\abdul\anaconda3\lib\threading.py", line 312, in wait
#     waiter.acquire()
# KeyboardInterrupt
# [W 2023-04-07 23:54:59,544] Trial 10 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [43], in <cell line: 42>()
#      42 if __name__ == "__main__":
#      43     study = optuna.create_study(direction="maximize")
# ---> 44     study.optimize(objective, n_trials=20)
#      45     print(study.best_trial)
#
# File ~\anaconda3\lib\site-packages\optuna\study\study.py:425, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     321 def optimize(
#     322     self,
#     323     func: ObjectiveFuncType,
#    (...)
#     330     show_progress_bar: bool = False,
#     331 ) -> None:
#     332     """Optimize an objective function.
#     333
#     334     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     422             If nested invocation of this method occurs.
#     423     """
# --> 425     _optimize(
#     426         study=self,
#     427         func=func,
#     428         n_trials=n_trials,
#     429         timeout=timeout,
#     430         n_jobs=n_jobs,
#     431         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     432         callbacks=callbacks,
#     433         gc_after_trial=gc_after_trial,
#     434         show_progress_bar=show_progress_bar,
#     435     )
#
# File ~\anaconda3\lib\site-packages\optuna\study\_optimize.py:66, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64 try:
#      65     if n_jobs == 1:
# ---> 66         _optimize_sequential(
#      67             study,
#      68             func,
#      69             n_trials,
#      70             timeout,
#      71             catch,
#      72             callbacks,
#      73             gc_after_trial,
#      74             reseed_sampler_rng=False,
#      75             time_start=None,
#      76             progress_bar=progress_bar,
#      77         )
#      78     else:
#      79         if n_jobs == -1:
#
# File ~\anaconda3\lib\site-packages\optuna\study\_optimize.py:163, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     160         break
#     162 try:
# --> 163     frozen_trial = _run_trial(study, func, catch)
#     164 finally:
#     165     # The following line mitigates memory problems that can be occurred in some
#     166     # environments (e.g., services that use computing containers such as GitHub Actions).
#     167     # Please refer to the following PR for further details:
#     168     # https://github.com/optuna/optuna/pull/325.
#     169     if gc_after_trial:
#
# File ~\anaconda3\lib\site-packages\optuna\study\_optimize.py:251, in _run_trial(study, func, catch)
#     244         assert False, "Should not reach."
#     246 if (
#     247     frozen_trial.state == TrialState.FAIL
#     248     and func_err is not None
#     249     and not isinstance(func_err, catch)
#     250 ):
# --> 251     raise func_err
#     252 return frozen_trial
#
# File ~\anaconda3\lib\site-packages\optuna\study\_optimize.py:200, in _run_trial(study, func, catch)
#     198 with get_heartbeat_thread(trial._trial_id, study._storage):
#     199     try:
# --> 200         value_or_values = func(trial)
#     201     except exceptions.TrialPruned as e:
#     202         # TODO(mamu): Handle multi-objective cases.
#     203         state = TrialState.PRUNED
#
# Input In [43], in objective(trial)
#      32      max_features = trial.suggest_int("max_features", 2,X_train.shape[1])
#      33      regressor_obj = sklearn.ensemble.RandomForestRegressor(random_state=17,  max_depth=max_depth, max_features=max_features )
# ---> 37 r2=sklearn.model_selection.cross_val_score(regressor_obj, x, y, n_jobs=-1, cv=3).mean()
#      39 return r2
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:515, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     512 # To ensure multimetric format is not supported
#     513 scorer = check_scoring(estimator, scoring=scoring)
# --> 515 cv_results = cross_validate(
#     516     estimator=estimator,
#     517     X=X,
#     518     y=y,
#     519     groups=groups,
#     520     scoring={"score": scorer},
#     521     cv=cv,
#     522     n_jobs=n_jobs,
#     523     verbose=verbose,
#     524     fit_params=fit_params,
#     525     pre_dispatch=pre_dispatch,
#     526     error_score=error_score,
#     527 )
#     528 return cv_results["test_score"]
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:266, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     263 # We clone the estimator to make sure that all the folds are
#     264 # independent, and that it is pickle-able.
#     265 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 266 results = parallel(
#     267     delayed(_fit_and_score)(
#     268         clone(estimator),
#     269         X,
#     270         y,
#     271         scorers,
#     272         train,
#     273         test,
#     274         verbose,
#     275         None,
#     276         fit_params,
#     277         return_train_score=return_train_score,
#     278         return_times=True,
#     279         return_estimator=return_estimator,
#     280         error_score=error_score,
#     281     )
#     282     for train, test in cv.split(X, y, groups)
#     283 )
#     285 _warn_or_raise_about_fit_failures(results, error_score)
#     287 # For callabe scoring, the return type is only know after calling. If the
#     288 # return type is a dictionary, the error scores can now be inserted with
#     289 # the correct key.
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:1056, in Parallel.__call__(self, iterable)
#    1053     self._iterating = False
#    1055 with self._backend.retrieval_context():
# -> 1056     self.retrieve()
#    1057 # Make sure that we get a last message telling us we are done
#    1058 elapsed_time = time.time() - self._start_time
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:935, in Parallel.retrieve(self)
#     933 try:
#     934     if getattr(self._backend, 'supports_timeout', False):
# --> 935         self._output.extend(job.get(timeout=self.timeout))
#     936     else:
#     937         self._output.extend(job.get())
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:542, in LokyBackend.wrap_future_result(future, timeout)
#     539 """Wrapper for Future.result to implement the same behaviour as
#     540 AsyncResults.get from multiprocessing."""
#     541 try:
# --> 542     return future.result(timeout=timeout)
#     543 except CfTimeoutError as e:
#     544     raise TimeoutError from e
#
# File ~\anaconda3\lib\concurrent\futures\_base.py:441, in Future.result(self, timeout)
#     438 elif self._state == FINISHED:
#     439     return self.__get_result()
# --> 441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     444     raise CancelledError()
#
# File ~\anaconda3\lib\threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %%
 print(study.best_params)

# %%
xgb = XGBRegressor(random_state=17,**study.best_params)
xgb.fit(X_train, y_train)
xbg_pred = xgb.predict(X_test)
print(r2_score(y_test, xgb_pred))
